# %%
import pandas as pd
pd.set_option('display.max_rows', 500)

# %%
srcDf=pd.read_excel( '/home/itv452844/myGit/justLearn/DataSets/electionresults/kerala/TLA_Data.xlsx',
    sheet_name="Sheet8",engine="openpyxl",header=[0,1])

# %%
srcDf.columns=srcDf.columns.to_flat_index()

# %%
display(srcDf)
# Out:
#      (Unnamed: 0_level_0, BOOTH_NO)  (UDF, 2011)  (UDF, 2016)  (BJP, 2011)  \
# 0                                 1          576          325           32
# 1                                 2          540          494           34
# 2                                 3          417          479           26
# 3                                 4          538          500           27
# 4                                 5          386          570           20
# 5                                 6          361          506           24
# 6                                 7          581          449           18
# 7                                 8          587          662           55
# 8                                 9          387          674           38
# 9                                10          494          473           28
# 10                               11          430          575           63
# ...
